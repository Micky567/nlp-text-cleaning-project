# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('mediumData.csv')
df.head()
# Out:
#               Names                                           Headings  \
# 0       umair haque                    How Britain’s Destroying Itself
# 1       umair haque          Will There Really Be a Next Donald Trump?
# 2        Levi Borba  10 Eye-Opening Charts Depicting the Shocking S...
# 3   Egberto Willies  Bernie Sanders on Sinema: She’s a corporate De...
# 4  Jessica Wildfire  I Don’t Want My Little Girl to Die on The Floo...
#
#                                                Links  \
# 0  https://medium.com/eudaimonia-co/how-britains-...
# 1  https://medium.com/eudaimonia-co/will-there-re...
# 2  https://medium.com/@leviborba/10-eye-opening-c...
# 3  https://medium.com/@egbertowillies/bernie-sand...
# 4  https://medium.com/@jessicalexicus/i-dont-want...
#
#                                          MainContent
# 0  How Britain’s Destroying ItselfWhat Happens Wh...
# 1  Will There Really Be a Next Donald Trump?Ameri...
# 2  10 Eye-Opening Charts Depicting the Shocking S...
# 3  Bernie Sanders on Sinema: She’s a corporate De...
# 4  I Don’t Want My Little Girl to Die on The Floo...

# %%
df.tail()
# Out:
#                   Names                                           Headings  \
# 5      Lauren Elizabeth  Bernie Sanders Has a Lot to Say About Kyrsten ...
# 6  Alexander Ziperovich                   Vladimir Putin’s Crushing Defeat
# 7        Jared A. Brock  IRS Tax Rules Run More Than 75,000 Pages. It C...
# 8                 Peter  Why Marjorie Taylor Greene is the real treat t...
# 9          Mike Weisser        Who Cares What Marjorie Taylor Greene Says?
#
#                                                Links  \
# 5  https://medium.com/@xlauren-mx/bernie-sanders-...
# 6  https://medium.com/@alexziperovich/vladimir-pu...
# 7  https://medium.com/surviving-tomorrow/irs-tax-...
# 8  https://medium.com/@korsh1968/why-marjorie-tay...
# 9  https://medium.com/@mikeweisser/who-cares-what...
#
#                                          MainContent
# 5  Bernie Sanders Has a Lot to Say About Kyrsten ...
# 6  PoliticsVladimir Putin’s Crushing DefeatThe an...
# 7  IRS Tax Rules Run More Than 75,000 Pages. It C...
# 8  Why Marjorie Taylor Greene is the real treat t...
# 9  Who Cares What Marjorie Taylor Greene Says?If ...

# %%
df.isnull()
# Out:
#    Names  Headings  Links  MainContent
# 0  False     False  False        False
# 1  False     False  False        False
# 2  False     False  False        False
# 3  False     False  False        False
# 4  False     False  False        False
# 5  False     False  False        False
# 6  False     False  False        False
# 7  False     False  False        False
# 8  False     False  False        False
# 9  False     False  False        False

# %%
df.shape
# Out:
# (10, 4)

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, HashingVectorizer

# %%
df.dropna()
# Out:
#                   Names                                           Headings  \
# 0           umair haque                    How Britain’s Destroying Itself
# 1           umair haque          Will There Really Be a Next Donald Trump?
# 2            Levi Borba  10 Eye-Opening Charts Depicting the Shocking S...
# 3       Egberto Willies  Bernie Sanders on Sinema: She’s a corporate De...
# 4      Jessica Wildfire  I Don’t Want My Little Girl to Die on The Floo...
# 5      Lauren Elizabeth  Bernie Sanders Has a Lot to Say About Kyrsten ...
# 6  Alexander Ziperovich                   Vladimir Putin’s Crushing Defeat
# 7        Jared A. Brock  IRS Tax Rules Run More Than 75,000 Pages. It C...
# 8                 Peter  Why Marjorie Taylor Greene is the real treat t...
# 9          Mike Weisser        Who Cares What Marjorie Taylor Greene Says?
# 1  https://medium.com/eudaimonia-co/will-there-re...
# 2  https://medium.com/@leviborba/10-eye-opening-c...
# 3  https://medium.com/@egbertowillies/bernie-sand...
# 4  https://medium.com/@jessicalexicus/i-dont-want...
# 5  https://medium.com/@xlauren-mx/bernie-sanders-...
# 6  https://medium.com/@alexziperovich/vladimir-pu...
# 7  https://medium.com/surviving-tomorrow/irs-tax-...
# 8  https://medium.com/@korsh1968/why-marjorie-tay...
# 9  https://medium.com/@mikeweisser/who-cares-what...
#
#                                          MainContent
# 0  How Britain’s Destroying ItselfWhat Happens Wh...
# 1  Will There Really Be a Next Donald Trump?Ameri...
# 2  10 Eye-Opening Charts Depicting the Shocking S...
# 3  Bernie Sanders on Sinema: She’s a corporate De...
# 4  I Don’t Want My Little Girl to Die on The Floo...
# 5  Bernie Sanders Has a Lot to Say About Kyrsten ...
# 6  PoliticsVladimir Putin’s Crushing DefeatThe an...
# 7  IRS Tax Rules Run More Than 75,000 Pages. It C...
# 8  Why Marjorie Taylor Greene is the real treat t...
# 9  Who Cares What Marjorie Taylor Greene Says?If ...

# %%
text['Headings'][6]
# Out:
# 'Vladimir Putin’s Crushing Defeat'

# %%
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
import re
ps = PorterStemmer()
corpus = []
for i in range(0, len(text)):
    review = re.sub('[^a-zA-Z]', ' ', text['Headings'][i])
    review = review.lower()
    review = review.split()
    
    review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
    review = ' '.join(review)
    corpus.append(review)

# %%
corpus[5]
# Out:
# 'berni sander lot say kyrsten sinema'

# %%
## Applying Countvectorizer
# Creating the Bag of Words model
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features=5000,ngram_range=(1,3))
X = cv.fit_transform(corpus).toarray()

# %%
cv.get_feature_names()[:20]
# Out:
# ['berni',
#  'berni sander',
#  'berni sander lot',
#  'berni sander sinema',
#  'britain',
#  'britain destroy',
#  'care',
#  'care marjori',
#  'care marjori taylor',
#  'chart',
#  'chart depict',
#  'chart depict shock',
#  'corpor',
#  'corpor democrat',
#  'corpor democrat sabotag',
#  'could',
#  'could three',
#  'could three sentenc',
#  'crush',
#  'crush defeat']

# %%
## Divide the dataset into Train and Test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=0)

# %%
cv.get_params()
# Out:
# {'analyzer': 'word',
#  'binary': False,
#  'decode_error': 'strict',
#  'dtype': numpy.int64,
#  'encoding': 'utf-8',
#  'input': 'content',
#  'lowercase': True,
#  'max_df': 1.0,
#  'max_features': 5000,
#  'min_df': 1,
#  'ngram_range': (1, 3),
#  'preprocessor': None,
#  'stop_words': None,
#  'strip_accents': None,
#  'token_pattern': '(?u)\\b\\w\\w+\\b',
#  'tokenizer': None,
#  'vocabulary': None}

# %%
X.shape
# Out:
# (10, 139)

# %%
y=text['Headings']

# %%
y
# Out:
# 0                      How Britain’s Destroying Itself
# 1            Will There Really Be a Next Donald Trump?
# 2    10 Eye-Opening Charts Depicting the Shocking S...
# 3    Bernie Sanders on Sinema: She’s a corporate De...
# 4    I Don’t Want My Little Girl to Die on The Floo...
# 5    Bernie Sanders Has a Lot to Say About Kyrsten ...
# 6                     Vladimir Putin’s Crushing Defeat
# 7    IRS Tax Rules Run More Than 75,000 Pages. It C...
# 8    Why Marjorie Taylor Greene is the real treat t...
# 9          Who Cares What Marjorie Taylor Greene Says?
# Name: Headings, dtype: object
